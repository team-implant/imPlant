# %%
import sys
import os

ml_service_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if ml_service_root not in sys.path:
    sys.path.append(ml_service_root)

import matplotlib.pyplot as plt
from ML.models.Temperature_models.temperature_linearRegression import run_temperature_regression
from ML.utills.jsonify import jsonify_predictions

model, X_test, y_test, y_pred, df = run_temperature_regression()

json_output = jsonify_predictions(
    df,
    X_test.index,
    y_pred,
    id_col="Id",  
    value_col="predictedTemperature",  
    timestamp_col="Timestamp",
    output_value_name="predictedTemperature"
)
print(json_output)

plt.figure(figsize=(10, 6))
plt.scatter(df["Timestamp"], df["Temperature"], label="All Data", alpha=0.5)
plt.scatter(df.loc[X_test.index, "Timestamp"], y_pred, color="red", label="Predictions")
plt.plot(df.loc[X_test.index, "Timestamp"], y_pred, color="red", linewidth=1, alpha=0.7)
plt.xlabel("Timestamp")
plt.ylabel("Temperature")
plt.title("Temperature Linear Regression")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# r^2 on train data is 0.0
# r^2 on test data is 0.0
# MSE on test data is 1.262177448353619e-29
# [
#   {
#     "id": 4,
#     "predictedTemperature": 22.600000379999997,
#     "timestamp": "2025-05-07T08:53:49"
#   },
#   {
#     "id": 17,
#     "predictedTemperature": 22.600000379999997,
#     "timestamp": "2025-05-07T08:54:38"
#   },
#   {
#     "id": 7,
#     "predictedTemperature": 22.600000379999997,
#     "timestamp": "2025-05-07T08:53:58"
#   },
#   {
#     "id": 11,
#     "predictedTemperature": 22.600000379999997,
#     "timestamp": "2025-05-07T08:54:20"
#   },
#   {
#     "id": 3,
#     "predictedTemperature": 22.600000379999997,
#     "timestamp": "2025-05-07T08:53:46"
#   }
# ]

# %%
from ML.models.Temperature_models.temperature_randomForest import run_temperature_random_forest
from ML.utills.jsonify import jsonify_predictions

model, X_test, y_test, y_pred, df = run_temperature_random_forest()

json_output = jsonify_predictions(
    df,
    X_test.index,
    y_pred,
    id_col="Id",  
    value_col="predictedTemperature",  
    timestamp_col="Timestamp",
    output_value_name="predictedTemperature"
)
print(json_output)

plt.figure(figsize=(10, 6))
plt.scatter(df["Timestamp"], df["Temperature"], label="All Data", alpha=0.5)
plt.scatter(df.loc[X_test.index, "Timestamp"], y_pred, color="green", label="RF Predictions")
plt.plot(df.loc[X_test.index, "Timestamp"], y_pred, color="green", linewidth=1, alpha=0.7)
plt.xlabel("Timestamp")
plt.ylabel("Temperature")
plt.title("Temperature Random Forest Regression")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# r^2 on train data is -15.0
# r^2 on test data is 0.0
# MSE on test data is 2.0194839173657902e-28
# [
#   {
#     "id": 4,
#     "predictedTemperature": 22.600000379999987,
#     "timestamp": "2025-05-07T08:53:49"
#   },
#   {
#     "id": 17,
#     "predictedTemperature": 22.600000379999987,
#     "timestamp": "2025-05-07T08:54:38"
#   },
#   {
#     "id": 7,
#     "predictedTemperature": 22.600000379999987,
#     "timestamp": "2025-05-07T08:53:58"
#   },
#   {
#     "id": 11,
#     "predictedTemperature": 22.600000379999987,
#     "timestamp": "2025-05-07T08:54:20"
#   },
#   {
#     "id": 3,
#     "predictedTemperature": 22.600000379999987,
#     "timestamp": "2025-05-07T08:53:46"
#   }
# ]
